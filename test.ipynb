# %%
from langchain_community.utilities import SerpAPIWrapper

# %%
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)
# Out:
# True

# %%
search = SerpAPIWrapper()

rephrased_question = "Could you let me know what finance‑related topic you’d like to discuss?"
    
search_results = search.run(rephrased_question)

search_results
# Out:
# "['This list explores various research topic ideas related to financial planning, focusing on the effects of financial literacy, the adoption of digital tools, ...', '9 Financial Topics You Need an Understanding Of · 1. Budgeting · 2. Debt · 3. Net worth · 4. Credit · 5. Saving · 6. Investing · 7. Homeownership · 8.', 'Budgeting, Debt, Credit, Savings, Emergency Fund, Retirement, Tracking Spending, Investing. Those are the basics. You mean like that or more ...', 'Finance Research Paper Topics for Academic Projects. Analyzing the Role of Central Banks in Economic Stability; Corporate Governance and Firm ...', 'Understanding credit cards; personal financial budgeting; living according to your means; avoiding debt that you cannot afford to repay; ...', 'Our monthly Wednesday Webinar series is designed for college planning professionals and folks in the field of financial aid.', 'YouTube, podcasts, and financial firm websites are great places to begin. Books, libraries, and courses provide deeper learning on specific financial topics.', 'Hi SS! looking for topic suggestions for a podcast about personal finances. My wife & I are kicking off a new project namely a podcast ...', 'The five principles of financial literacy enable you to use money wisely, make informed decisions about your finances, create budgets, manage debt and plan ...']"

# %%
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage
import os

def get_groq_llm():
    return ChatOpenAI(
        model="openai/gpt-oss-20b",  # or another Groq model you have access to
        base_url="https://api.groq.com/openai/v1",
        api_key=os.getenv("GROQ_API_KEY"),
        temperature=0.7,
        max_tokens=1024,
    )

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

llm = get_groq_llm()

template = """You are helpful Assistant. Help the user to get the Answer for the asked question based on the following context which is coming from internet search results.

Context: {context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)
rag_chain = prompt | llm

# %%
rag_chain.invoke(
    {
        "context": search_results,
        "question": rephrased_question,
    }
)
# Out:
# AIMessage(content='Sure! One engaging finance‑related topic you could explore is:\n\n**“How Digital Financial Tools (Apps, AI‑Driven Advisors, and Blockchain) are Reshaping Personal Financial Literacy and Decision‑Making.”**\n\n*Why it’s interesting:*  \n- **Relevance:** With the rapid rise of fintech, more people are managing budgets, investing, and planning for retirement through apps and AI tools.  \n- **Impact:** Examine how these tools help (or hinder) users in understanding budgeting, debt management, and long‑term investing.  \n- **Research angle:** Look at studies on digital literacy, user trust in automated advice, and the effectiveness of gamified savings features.  \n- **Practical take‑away:** Offer insights for listeners or readers on selecting trustworthy tools, spotting red flags, and integrating tech into a holistic financial plan.\n\nFeel free to tweak the angle—e.g., focus on a specific demographic (students, retirees) or a particular tool (budgeting apps vs. robo‑advisors). Let me know if you’d like more ideas or a deeper dive into this topic!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 402, 'prompt_tokens': 397, 'total_tokens': 799, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'queue_time': 0.050980745, 'prompt_time': 0.025901175, 'completion_time': 0.358657564, 'total_time': 0.384558739}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_ebaf47239f', 'id': 'chatcmpl-970cf012-c71a-401a-8cde-98fd60416e4c', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--7a3979f4-939e-4ad7-a5e2-b449b1e4497e-0', usage_metadata={'input_tokens': 397, 'output_tokens': 402, 'total_tokens': 799, 'input_token_details': {}, 'output_token_details': {}})

# %%
print(rag_chain.invoke(
    {
        "context": search_results,
        "question": rephrased_question,
    }
).content)
# Out:
# Sure! How about exploring **“The Impact of Financial Literacy on Retirement Planning”**? It covers budgeting, saving, investing, and the role of education in helping people build a secure retirement.
